# %%
# %matplotlib inline
# %run test --model cyclegan2 --preprocess RAC --load_model 20 --examples 2 --phase train --visuals
# Out:
# ----------------- Options ---------------
#                       all: False
#                   backend: None
#                batch_size: 1
#           checkpoints_dir: ./checkpoints
#                     cloud: aws
#                 crop_size: 256
#                        ct: None
#              current_host:
#                 direction: AtoB
#                  examples: 2                             	[default: 1]
#                     hosts: ['algo-1', 'algo-2']
#                   isTrain: False                         	[default: None]
#                load_model: 20                            	[default: latest]
#                 load_size: 286
#                   log_out: False
#                    logger: <Logger UWIE (DEBUG)>         	[default: None]
#                     model: cyclegan2                     	[default: None]
#                 model_dir: F:\Projects\Underwater-image-enhancement\output\model
#                n_blocks_G: 9
#                n_layers_D: 3
# ...
