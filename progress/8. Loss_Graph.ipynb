# %%
import pickle
import matplotlib.pyplot as plt

# %%
filename = './models_uwie_v161_loss_stats.pkl'

# %%
with open(filename, 'rb') as f:
    losses = pickle.load(f)

# %%
plt.figure(figsize=(10,5))
plt.plot(losses['loss_idt_A'])
plt.plot(losses['loss_idt_B'])

# %%
plt.figure(figsize=(10,5))
plt.plot(losses['loss_D_A'])
plt.plot(losses['loss_D_B'])

# %%
plt.figure(figsize=(10,5))
plt.plot(losses['loss_G_AtoB'])
plt.plot(losses['loss_G_BtoA'])

# %%
plt.figure(figsize=(10,5))
plt.plot(losses['cycle_loss_A'])
plt.plot(losses['cycle_loss_B'])
