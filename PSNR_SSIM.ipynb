# %%
import pickle
import matplotlib.pyplot as plt

# %%
columns = list(range(26, 72))
ranges = [0,0.05,0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5,0.55,0.6,0.65,0.7,0.75,0.8,0.85,0.9,0.95,1]

pkl_file_paths = list()
for f_name in columns:
    pkl_file_paths.append(f"output/{f_name}_data.pkl")

final_matrix = list()
for pkl_file_path in pkl_file_paths:
    with open(pkl_file_path, "rb") as pkl_file:
        pkl_file_data = pickle.load(pkl_file)
        final_matrix.append(pkl_file_data.get("ssim"))

# %%
import numpy as np

data_matrix = np.matrix(final_matrix).transpose()

print(data_matrix)
# Out:
# [[0.10866062 0.51568529 0.22444705 ... 0.34423596 0.09986859 0.4783325 ]
#  [0.31973134 0.14477021 0.21599169 ... 0.1627291  0.18402479 0.24125876]
#  [0.11325355 0.18101708 0.09787467 ... 0.08412999 0.2008015  0.09572506]
#  ...
#  [0.060562   0.06102092 0.16059852 ... 0.22608195 0.17378925 0.49206108]
#  [0.22209687 0.17442226 0.12826527 ... 0.16865102 0.23766937 0.16328454]
#  [0.10019214 0.23420325 0.10926383 ... 0.02988141 0.17665861 0.07191701]]

# %%
import pandas as pd

df = pd.DataFrame(data_matrix, columns = columns)
display(df)
# Out:
#             26        27        28        29        30        31        32  \
# 0     0.108661  0.515685  0.224447  0.230230  0.203240  0.286938  0.171612
# 1     0.319731  0.144770  0.215992  0.578684  0.482951  0.077322  0.149660
# 2     0.113254  0.181017  0.097875  0.446861  0.229272  0.188507  0.174493
# 3     0.091333  0.060213  0.236344  0.070358  0.313657  0.203685  0.277934
# 4     0.198996  0.359987  0.097140  0.083199  0.151809  0.355023  0.184840
# ...        ...       ...       ...       ...       ...       ...       ...
# 5545  0.254603  0.153227  0.323373  0.509926  0.156907  0.245557  0.100420
# 5546  0.150320  0.285649  0.277502  0.058513  0.064540  0.212731  0.340452
# 5547  0.060562  0.061021  0.160599  0.178761  0.158078  0.159476  0.085312
# 5548  0.222097  0.174422  0.128265  0.208754  0.310668  0.124092  0.107623
# 5549  0.100192  0.234203  0.109264  0.157473  0.278327  0.168799  0.135922
#
#             33        34        35  ...        62        63        64  \
# 0     0.307344  0.240458  0.207830  ...  0.190747  0.073386  0.094017
# 1     0.108827  0.529769  0.061391  ...  0.104774  0.119238  0.046361
# 2     0.342123  0.123672  0.175867  ...  0.063650  0.177933  0.191788
# 3     0.207164  0.561455  0.386520  ...  0.162363  0.389766  0.397996
# 4     0.168085  0.168208  0.135368  ...  0.445243  0.092032  0.201232
# ...        ...       ...       ...  ...       ...       ...       ...
# 5545  0.188802  0.346330  0.259664  ...  0.211680  0.070980  0.227674
# 5546  0.324819  0.139564  0.113638  ...  0.441099  0.109041  0.073804
# 5547  0.244035  0.184865  0.472827  ...  0.096521  0.137866  0.116902
# 5548  0.375095  0.267921  0.219848  ...  0.241256  0.096754  0.048461
# 5549  0.133891  0.202015  0.095809  ...  0.241772  0.039197  0.453591
#
#             65        66        67        68        69        70        71
# 0     0.167093  0.641726  0.576244  0.160479  0.344236  0.099869  0.478332
# 1     0.101211  0.188999  0.025531  0.180169  0.162729  0.184025  0.241259
# 2     0.401442  0.088511  0.301836  0.227051  0.084130  0.200802  0.095725
# 3     0.619342  0.115215  0.062494  0.334860  0.091813  0.102984  0.097608
# 4     0.324776  0.267800  0.474491  0.191088  0.126493  0.324158  0.169164
# ...        ...       ...       ...       ...       ...       ...       ...
# 5545  0.195381  0.092358  0.095036  0.403086  0.133043  0.205963  0.238961
# 5546  0.110793  0.605545  0.264316  0.140427  0.351757  0.150431  0.100100
# 5547  0.115899  0.083840  0.086185  0.261971  0.226082  0.173789  0.492061
# 5548  0.144206  0.049850  0.193310  0.117462  0.168651  0.237669  0.163285
# 5549  0.152300  0.403528  0.060282  0.465406  0.029881  0.176659  0.071917
#
# [5550 rows x 46 columns]

# %%
df.mean().plot(figsize=(16,8))
# Out:
# <AxesSubplot:>

# %%
df.median().plot(figsize=(16,8))
# Out:
# <AxesSubplot:>

# %%
df[70].value_counts(bins=20, sort=False)
# Out:
# (0.00845, 0.0489]     104
# (0.0489, 0.0876]      724
# (0.0876, 0.126]      1089
# (0.126, 0.165]        973
# (0.165, 0.204]        741
# (0.204, 0.242]        495
# (0.242, 0.281]        336
# (0.281, 0.32]         273
# (0.32, 0.358]         203
# (0.358, 0.397]        161
# (0.397, 0.436]        107
# (0.436, 0.474]         99
# (0.474, 0.513]         69
# (0.513, 0.552]         71
# (0.552, 0.59]          41
# (0.59, 0.629]          24
# (0.629, 0.668]         18
# (0.668, 0.706]         10
# (0.706, 0.745]          6
# (0.745, 0.784]          6
# Name: 70, dtype: int64

# %%
matrix = np.array([df[column].groupby(pd.cut(df[column], ranges)).count().values for column in df.columns.values]).transpose()
out = pd.DataFrame(matrix, columns= df.columns.values)

# %%
out.plot(figsize=(20,20))
# Out:
# <AxesSubplot:>

# %%
out.plot(figsize=(20,20), kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>
