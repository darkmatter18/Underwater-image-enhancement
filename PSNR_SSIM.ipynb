# %%
import pickle
import matplotlib.pyplot as plt

# %%
columns = list(range(26, 108))
ranges = [0,0.05,0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5,0.55,0.6,0.65,0.7,0.75,0.8,0.85,0.9,0.95,1]

pkl_file_paths = list()
for f_name in columns:
    pkl_file_paths.append(f"output/{f_name}_data.pkl")

final_matrix = list()
for pkl_file_path in pkl_file_paths:
    with open(pkl_file_path, "rb") as pkl_file:
        pkl_file_data = pickle.load(pkl_file)
        ssim = pkl_file_data.get("ssim")
        print(f"Length of {pkl_file_path} is {len(ssim)}")
        final_matrix.append(ssim)
# Out:
# Length of output/26_data.pkl is 5550
# Length of output/27_data.pkl is 5550
# Length of output/28_data.pkl is 5550
# Length of output/29_data.pkl is 5550
# Length of output/30_data.pkl is 5550
# Length of output/31_data.pkl is 5550
# Length of output/32_data.pkl is 5550
# Length of output/33_data.pkl is 5550
# Length of output/34_data.pkl is 5550
# Length of output/35_data.pkl is 5550
# Length of output/36_data.pkl is 5550
# Length of output/37_data.pkl is 5550
# Length of output/38_data.pkl is 5550
# Length of output/39_data.pkl is 5550
# Length of output/40_data.pkl is 5550
# Length of output/41_data.pkl is 5550
# Length of output/42_data.pkl is 5550
# Length of output/43_data.pkl is 5550
# Length of output/44_data.pkl is 5550
# Length of output/45_data.pkl is 5550
# Length of output/46_data.pkl is 5550
# Length of output/47_data.pkl is 5550
# Length of output/48_data.pkl is 5550
# Length of output/49_data.pkl is 5550
# Length of output/50_data.pkl is 5550
# Length of output/51_data.pkl is 5550
# Length of output/52_data.pkl is 5550
# Length of output/53_data.pkl is 5550
# Length of output/54_data.pkl is 5550
# Length of output/55_data.pkl is 5550
# Length of output/56_data.pkl is 5550
# Length of output/57_data.pkl is 5550
# Length of output/58_data.pkl is 5550
# Length of output/59_data.pkl is 5550
# Length of output/60_data.pkl is 5550
# Length of output/61_data.pkl is 5550
# Length of output/62_data.pkl is 5550
# Length of output/63_data.pkl is 5550
# Length of output/64_data.pkl is 5550
# Length of output/65_data.pkl is 5550
# Length of output/66_data.pkl is 5550
# Length of output/67_data.pkl is 5550
# Length of output/68_data.pkl is 5550
# Length of output/69_data.pkl is 5550
# Length of output/70_data.pkl is 5550
# Length of output/71_data.pkl is 5550
# Length of output/72_data.pkl is 5550
# Length of output/73_data.pkl is 5550
# Length of output/74_data.pkl is 5550
# Length of output/75_data.pkl is 5550
# Length of output/76_data.pkl is 5550
# Length of output/77_data.pkl is 5550
# Length of output/78_data.pkl is 5550
# Length of output/79_data.pkl is 5550
# Length of output/80_data.pkl is 5550
# Length of output/81_data.pkl is 5550
# Length of output/82_data.pkl is 5550
# Length of output/83_data.pkl is 5550
# Length of output/84_data.pkl is 5550
# Length of output/85_data.pkl is 5550
# Length of output/86_data.pkl is 5550
# Length of output/87_data.pkl is 5550
# Length of output/88_data.pkl is 5550
# Length of output/89_data.pkl is 5550
# Length of output/90_data.pkl is 5550
# Length of output/91_data.pkl is 5550
# Length of output/92_data.pkl is 5550
# Length of output/93_data.pkl is 5550
# Length of output/94_data.pkl is 5550
# Length of output/95_data.pkl is 5550
# Length of output/96_data.pkl is 5550
# Length of output/97_data.pkl is 5550
# Length of output/98_data.pkl is 5550
# Length of output/99_data.pkl is 5550
# Length of output/100_data.pkl is 5550
# Length of output/101_data.pkl is 5550
# Length of output/102_data.pkl is 5550
# Length of output/103_data.pkl is 5550
# Length of output/104_data.pkl is 5550
# Length of output/105_data.pkl is 5550
# Length of output/106_data.pkl is 5550
# Length of output/107_data.pkl is 5550

# %%
import numpy as np

data_matrix = np.matrix(final_matrix).transpose()
data_matrix.shape
# Out:
# (5550, 82)

# %%
import pandas as pd

df = pd.DataFrame(data_matrix, columns = columns)

# %%
df.mean().plot(figsize=(16,8))
# Out:
# <AxesSubplot:>

# %%
df.median().plot(figsize=(16,8))
# Out:
# <AxesSubplot:>

# %%
df[107].value_counts(bins=20, sort=False)
# Out:
# (0.00818, 0.0493]     115
# (0.0493, 0.0887]      751
# (0.0887, 0.128]      1082
# (0.128, 0.167]        942
# (0.167, 0.207]        724
# (0.207, 0.246]        477
# (0.246, 0.285]        346
# (0.285, 0.325]        275
# (0.325, 0.364]        204
# (0.364, 0.404]        158
# (0.404, 0.443]        127
# (0.443, 0.482]         97
# (0.482, 0.522]         72
# (0.522, 0.561]         72
# (0.561, 0.6]           42
# (0.6, 0.64]            26
# (0.64, 0.679]          14
# (0.679, 0.718]         14
# (0.718, 0.758]          5
# (0.758, 0.797]          7
# Name: 107, dtype: int64

# %%
df[56].value_counts(bins=20, sort=False)
# Out:
# (0.008, 0.0486]       96
# (0.0486, 0.0874]     672
# (0.0874, 0.126]     1046
# (0.126, 0.165]       953
# (0.165, 0.204]       770
# (0.204, 0.243]       510
# (0.243, 0.281]       353
# (0.281, 0.32]        283
# (0.32, 0.359]        211
# (0.359, 0.398]       182
# (0.398, 0.437]       123
# (0.437, 0.475]        90
# (0.475, 0.514]        74
# (0.514, 0.553]        75
# (0.553, 0.592]        44
# (0.592, 0.63]         27
# (0.63, 0.669]         20
# (0.669, 0.708]        10
# (0.708, 0.747]         6
# (0.747, 0.786]         5
# Name: 56, dtype: int64

# %%
matrix = np.array([df[column].groupby(pd.cut(df[column], ranges)).count().values for column in df.columns.values]).transpose()
out = pd.DataFrame(matrix, columns= df.columns.values)

# %%
out.plot(figsize=(20,20))
# Out:
# <AxesSubplot:>

# %%
out.plot(figsize=(20,20), kind="hist")
