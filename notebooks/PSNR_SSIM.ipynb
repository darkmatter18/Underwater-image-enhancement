# %%
import pickle
import matplotlib.pyplot as plt

# %%
columns = list(range(26, 114))
ranges = [0,0.05,0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5,0.55,0.6,0.65,0.7,0.75,0.8,0.85,0.9,0.95,1]

pkl_file_paths = list()
for f_name in columns:
    pkl_file_paths.append(f"output/metrics/{f_name}_data.pkl")

final_matrix = list()
for pkl_file_path in pkl_file_paths:
    with open(pkl_file_path, "rb") as pkl_file:
        pkl_file_data = pickle.load(pkl_file)
        ssim = pkl_file_data.get("ssim")
        print(f"Length of {pkl_file_path} is {len(ssim)}")
        final_matrix.append(ssim)
# Out:
# Length of output/metrics/26_data.pkl is 5550
# Length of output/metrics/27_data.pkl is 5550
# Length of output/metrics/28_data.pkl is 5550
# Length of output/metrics/29_data.pkl is 5550
# Length of output/metrics/30_data.pkl is 5550
# Length of output/metrics/31_data.pkl is 5550
# Length of output/metrics/32_data.pkl is 5550
# Length of output/metrics/33_data.pkl is 5550
# Length of output/metrics/34_data.pkl is 5550
# Length of output/metrics/35_data.pkl is 5550
# Length of output/metrics/36_data.pkl is 5550
# Length of output/metrics/37_data.pkl is 5550
# Length of output/metrics/38_data.pkl is 5550
# Length of output/metrics/39_data.pkl is 5550
# Length of output/metrics/40_data.pkl is 5550
# Length of output/metrics/41_data.pkl is 5550
# Length of output/metrics/42_data.pkl is 5550
# Length of output/metrics/43_data.pkl is 5550
# Length of output/metrics/44_data.pkl is 5550
# Length of output/metrics/45_data.pkl is 5550
# Length of output/metrics/46_data.pkl is 5550
# ...

# %%
import numpy as np

data_matrix = np.matrix(final_matrix).transpose()
data_matrix.shape
# Out:
# (5550, 88)

# %%
import pandas as pd

df = pd.DataFrame(data_matrix, columns = columns)

# %%
df.mean()[:-1].plot(figsize=(16,8))
# Out:
# <AxesSubplot:>

# %%
df.median()[:-1].plot(figsize=(16,8))
# Out:
# <AxesSubplot:>

# %%
df[112].value_counts(bins=20, sort=False)
# Out:
# (0.0125, 0.052]     81
# (0.052, 0.0898]    587
# (0.0898, 0.128]    983
# (0.128, 0.165]     995
# (0.165, 0.203]     820
# (0.203, 0.241]     557
# (0.241, 0.279]     400
# (0.279, 0.316]     321
# (0.316, 0.354]     219
# (0.354, 0.392]     170
# (0.392, 0.43]      127
# (0.43, 0.468]      107
# (0.468, 0.505]      51
# (0.505, 0.543]      51
# (0.543, 0.581]      32
# (0.581, 0.619]      19
# (0.619, 0.656]      16
# (0.656, 0.694]       7
# (0.694, 0.732]       5
# (0.732, 0.77]        2
# Name: 112, dtype: int64

# %%
df[56].value_counts(bins=20, sort=False)
# Out:
# (0.008, 0.0486]       96
# (0.0486, 0.0874]     672
# (0.0874, 0.126]     1046
# (0.126, 0.165]       953
# (0.165, 0.204]       770
# (0.204, 0.243]       510
# (0.243, 0.281]       353
# (0.281, 0.32]        283
# (0.32, 0.359]        211
# (0.359, 0.398]       182
# (0.398, 0.437]       123
# (0.437, 0.475]        90
# (0.475, 0.514]        74
# (0.514, 0.553]        75
# (0.553, 0.592]        44
# (0.592, 0.63]         27
# (0.63, 0.669]         20
# (0.669, 0.708]        10
# (0.708, 0.747]         6
# (0.747, 0.786]         5
# Name: 56, dtype: int64

# %%
matrix = np.array([df[column].groupby(pd.cut(df[column], ranges)).count().values for column in df.columns.values]).transpose()
out = pd.DataFrame(matrix, columns= df.columns.values)

# %%
out.plot(figsize=(20,20))
# Out:
# <AxesSubplot:>

# %%
out.plot(figsize=(20,20), kind="hist")
